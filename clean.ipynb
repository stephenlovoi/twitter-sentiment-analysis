# %%
import pandas as pd
path = 'Resources/trump_archive.csv'
df = pd.read_csv(path)
df
# Out:
#        Unnamed: 0                                               text  \
# 0               0  Republicans and Democrats have both created ou...
# 1               2  The Unsolicited Mail In Ballot Scam is a major...
# 2              11  The threshold identification of Ballots is tur...
# 3              16  Nevada is turning out to be a cesspool of Fake...
# 4              18  Wisconsin is looking very good. Needs a little...
# ...           ...                                                ...
# 30911       46684  As hard as I work, &amp, as successful as our ...
# 30912       46685  95% Approval Rating in the Republican Party. T...
# 30913       46688  ....different places that he thought were wast...
# 30914       46689  Iran never won a war, but never lost a negotia...
# 30915       46692  Just signed an order to support the workers of...
#
#       isRetweet  favorites  retweets                 date
# 0             f         49       255  2011-08-02 18:07:48
# 1             f      80527     23502  2020-09-12 20:10:58
# 2             f     493076    100609  2020-11-09 19:36:26
# 3             f     363489     78378  2020-11-09 19:54:33
# 4             f     347994     61006  2020-11-09 20:02:19
# ...         ...        ...       ...                  ...
# 30911         f     255804     43544  2020-01-04 22:16:27
# 30912         f     312578     38960  2020-01-04 14:57:14
# 30913         f      55568     11319  2020-01-03 17:27:08
# 30914         f     303007     57253  2020-01-03 12:44:30
# 30915         f     176289     36001  2020-10-22 21:04:21
#
# [30916 rows x 6 columns]

# %%
# Drop unnecessary columns, drop retweeted columns
df = df.drop(['id', 'isDeleted', 'device', 'isFlagged',], axis=1)
df = df.loc[df['isRetweet'] != 't']

# %%
# Drop rows with links 
df = df.loc[df['text'].str.contains('https') == False]
df
# Out:
#                                                     text isRetweet  favorites  \
# 0      Republicans and Democrats have both created ou...         f         49
# 1      The Unsolicited Mail In Ballot Scam is a major...         f      80527
# 2      The threshold identification of Ballots is tur...         f     493076
# 3      Nevada is turning out to be a cesspool of Fake...         f     363489
# 4      Wisconsin is looking very good. Needs a little...         f     347994
# ...                                                  ...       ...        ...
# 30911  As hard as I work, &amp, as successful as our ...         f     255804
# 30912  95% Approval Rating in the Republican Party. T...         f     312578
# 30913  ....different places that he thought were wast...         f      55568
# 30914  Iran never won a war, but never lost a negotia...         f     303007
# 30915  Just signed an order to support the workers of...         f     176289
#
#        retweets                 date
# 0           255  2011-08-02 18:07:48
# 1         23502  2020-09-12 20:10:58
# 2        100609  2020-11-09 19:36:26
# 3         78378  2020-11-09 19:54:33
# 4         61006  2020-11-09 20:02:19
# ...         ...                  ...
# 30911     43544  2020-01-04 22:16:27
# 30912     38960  2020-01-04 14:57:14
# 30913     11319  2020-01-03 17:27:08
# 30914     57253  2020-01-03 12:44:30
# 30915     36001  2020-10-22 21:04:21
#
# [30916 rows x 5 columns]

# %%
df.to_csv('Resources/trump_archive.csv')
