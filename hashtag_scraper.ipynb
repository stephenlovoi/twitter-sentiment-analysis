# %%
import csv
import tweepy as tw
import pandas as pd

# %run ./config.ipynb

# %%
auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
# insert hashtag or keyword in 'search_words' to get results you are looking for
search_words = "climate-change"
date_since = "2021-01-01"

username = []
location = []
text = []
hashtags = []
time = []

for i in tw.Cursor(api.search, q=search_words+' -filter:retweets', lang="en", since=date_since, tweet_mode='extended').items(3200):
    username.append(i.user.screen_name)
    location.append(i.user.location)
    text.append(i.full_text)
    hashtags.append(i.entities['hashtags'])
    time.append(i.created_at)

# %%
df = pd.DataFrame({'username': username, 'text':text, 'time':time})
df
# Out:
#              username                                               text  \
# 0        RBrodziansky  @KlikEDM @emmakennytv Vast majority of the wor...
# 1           mememia11  @itvnews @rafredarrows What about climate chan...
# 2        MediawatchNZ  The Climate Change Commission's first blueprin...
# 3          jessmarbio  @TheMushyPea My father is the opposite. Doesn'...
# 4     MadisonDemSuptr  @LindaSalem @ChristopherHahn @TheDemCoalition ...
# ...               ...                                                ...
# 3195       greekzebra  G7 Is Just Another Meeting Of the Globalists U...
# 3196        Jester572  @michael_saylor The entire "climate change" is...
# 3197   hadler21346999  Wo er recht hat, hat er recht.\n\nBill Gates: ...
# 3198      ZitaFewster  When we think about climate change, everything...
# 3199   RevJohnHMoore1  There is a plethora of issues awaiting the att...
#
#                     time
# 0    2021-06-12 21:16:50
# 1    2021-06-12 21:16:27
# ...
